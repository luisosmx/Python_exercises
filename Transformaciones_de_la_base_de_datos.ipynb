# %% [markdown]
# <a href="https://colab.research.google.com/github/luisosmx/Python_exercises/blob/main/Transformaciones_de_la_base_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/airline_dec_2008_50k.csv')
# Out:
# <ipython-input-1-dcc53ca8087d>:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/airline_dec_2008_50k.csv')

# %%
df['HoursDelay'] = round(df['ArrDelay'] / 60)

# %%
df['HoursDelay'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: HoursDelay, dtype: float64

# %%
df.drop(['Diverted', 'Cancelled', 'Year'], axis = 1)
# Out:
#        Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0               1     12           1          1      NaN        1000      NaN
# 1               2     12           1          1      NaN        1000      NaN
# 2               3     12           1          1      NaN        1000      NaN
# 3               4     12           1          1      NaN        1000      NaN
# 4               5     12           1          1      NaN        1000      NaN
# ...           ...    ...         ...        ...      ...         ...      ...
# 49995       49996     12          13          6    805.0         810    900.0
# 49996       49997     12          13          6    805.0         810    906.0
# 49997       49998     12          13          6    805.0         810    925.0
# 49998       49999     12          13          6    805.0         810    938.0
# 49999       50000     12          13          6    806.0         800    935.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... Distance  TaxiIn  TaxiOut  \
# 0            1100            WN         16  ...      239     NaN      NaN
# 1            1110            US       2122  ...      185     NaN      NaN
# 2            1125            MQ       3155  ...      417     NaN      NaN
# 3            1227            EV       4980  ...      403     NaN      NaN
# 4            1227            NW       1406  ...      235     NaN      NaN
# ...           ...           ...        ...  ...      ...     ...      ...
# 49995         904            YV       2891  ...      110    10.0     16.0
# 49996         916            CO        414  ...      224     7.0     13.0
# 49997         940            WN        505  ...      423     2.0     10.0
# 49998         945            AA       1336  ...      551     4.0     14.0
# 49999         935            MQ       4673  ...      426     9.0     15.0
#
#        CancellationCode  CarrierDelay  WeatherDelay NASDelay SecurityDelay  \
# 0                     A           NaN           NaN      NaN           NaN
# 1                     A           NaN           NaN      NaN           NaN
# 2                     B           NaN           NaN      NaN           NaN
# 3                     C           NaN           NaN      NaN           NaN
# 4                     B           NaN           NaN      NaN           NaN
# ...                 ...           ...           ...      ...           ...
# 49995               NaN           NaN           NaN      NaN           NaN
# 49996               NaN           NaN           NaN      NaN           NaN
# 49997               NaN           NaN           NaN      NaN           NaN
# 49998               NaN           NaN           NaN      NaN           NaN
# 49999               NaN           NaN           NaN      NaN           NaN
#
#        LateAircraftDelay  HoursDelay
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3                    NaN         NaN
# 4                    NaN         NaN
# ...                  ...         ...
# 49995                NaN        -0.0
# 49996                NaN        -0.0
# 49997                NaN        -0.0
# 49998                NaN        -0.0
# 49999                NaN         0.0
#
# [50000 rows x 28 columns]

# %% [markdown]
# #Groupby: obtener informacion esencial

# %%
df = pd.read_csv('/content/airline_dec_2008_50k.csv')
# Out:
# <ipython-input-5-3c16f56a4b81>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/airline_dec_2008_50k.csv')

# %%
df.groupby(by = 'DayOfWeek')['ArrDelay'].describe()
# Out:
#             count      mean        std   min   25%  50%   75%     max
# DayOfWeek
# 1          5619.0  8.082043  34.409537 -62.0 -10.0 -1.0  12.0   314.0
# 2          5072.0 -0.261041  21.982247 -50.0 -11.0 -4.0   5.0   355.0
# 3          4970.0 -1.751107  17.627191 -71.0 -12.0 -5.0   4.0   216.0
# 4          4999.0 -0.571114  20.163271 -43.0 -11.0 -4.0   5.0   347.0
# 5          5109.0 -1.570170  18.933228 -50.0 -11.0 -4.0   4.0   298.0
# 6          3724.0 -2.928571  19.550969 -53.0 -13.0 -6.0   3.0   273.0
# 7          1874.0 -1.520811  34.164716 -37.0 -13.0 -6.0   3.0  1103.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['std'].plot(kind='hist', bins=20, title='std')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='count', y='mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='mean', y='std', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='std', y='min', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='min', y='25%', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['count'].plot(kind='line', figsize=(8, 4), title='count')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['std'].plot(kind='line', figsize=(8, 4), title='std')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['min'].plot(kind='line', figsize=(8, 4), title='min')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.groupby(by = 'DayOfWeek')['ArrDelay', 'DepDelay'].mean()
# Out:
# <ipython-input-7-4f31f3088667>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = 'DayOfWeek')['ArrDelay', 'DepDelay'].mean()
#            ArrDelay  DepDelay
# DayOfWeek
# 1          8.082043  8.423018
# 2         -0.261041  4.292714
# 3         -1.751107  2.536659
# 4         -0.571114  1.265507
# 5         -1.570170  2.779245
# 6         -2.928571  1.242739
# 7         -1.520811  5.973281
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['ArrDelay'].plot(kind='hist', bins=20, title='ArrDelay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['DepDelay'].plot(kind='hist', bins=20, title='DepDelay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14.plot(kind='scatter', x='ArrDelay', y='DepDelay', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['ArrDelay'].plot(kind='line', figsize=(8, 4), title='ArrDelay')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['DepDelay'].plot(kind='line', figsize=(8, 4), title='DepDelay')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['DayOfWeek'].plot(kind='hist', bins=20, title='DayOfWeek')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['ArrDelay'].plot(kind='hist', bins=20, title='ArrDelay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['DepDelay'].plot(kind='hist', bins=20, title='DepDelay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='DayOfWeek', y='ArrDelay', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='ArrDelay', y='DepDelay', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayOfWeek']
#   ys = series['ArrDelay']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('DayOfWeek', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayOfWeek')
# _ = plt.ylabel('ArrDelay')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayOfWeek']
#   ys = series['DepDelay']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('DayOfWeek', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayOfWeek')
# _ = plt.ylabel('DepDelay')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['DayOfWeek']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'DayOfWeek'}, axis=1)
#               .sort_values('DayOfWeek', ascending=True))
#   xs = counted['DayOfWeek']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_24.sort_values('DayOfWeek', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayOfWeek')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25['DayOfWeek'].plot(kind='line', figsize=(8, 4), title='DayOfWeek')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['ArrDelay'].plot(kind='line', figsize=(8, 4), title='ArrDelay')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['DepDelay'].plot(kind='line', figsize=(8, 4), title='DepDelay')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.groupby(by = 'DayOfWeek')['ArrDelay'].max() - df.groupby(by = 'DayOfWeek')['ArrDelay'].min()
# Out:
# DayOfWeek
# 1     376.0
# 2     405.0
# 3     287.0
# 4     390.0
# 5     348.0
# 6     326.0
# 7    1140.0
# Name: ArrDelay, dtype: float64

# %%
dfATLHOU = df[df.Origin.isin(['ATL', 'HOU'])]

# %%
dfATLHOU.groupby(by = ['DayOfWeek', 'Origin'])['ArrDelay'].mean()
# Out:
# DayOfWeek  Origin
# 1          ATL       9.296804
#            HOU       4.555556
# 2          ATL       3.224719
#            HOU      -0.383333
# 3          ATL       5.453988
#            HOU      -4.400000
# 4          ATL      -1.520958
#            HOU       0.758621
# 5          ATL       6.719298
#            HOU       0.785714
# 6          ATL      -1.000000
#            HOU      -4.388889
# 7          ATL       3.549020
#            HOU      -4.000000
# Name: ArrDelay, dtype: float64

# %%
dfATLHOU.groupby(by = ['Origin', 'DayOfWeek'])['ArrDelay'].mean()
# Out:
# Origin  DayOfWeek
# ATL     1            9.296804
#         2            3.224719
#         3            5.453988
#         4           -1.520958
#         5            6.719298
#         6           -1.000000
#         7            3.549020
# HOU     1            4.555556
#         2           -0.383333
#         3           -4.400000
#         4            0.758621
#         5            0.785714
#         6           -4.388889
#         7           -4.000000
# Name: ArrDelay, dtype: float64

# %% [markdown]
# #Tratar datos duplicados y perdidos

# %%
 df = pd.read_csv('/content/airline_dec_2008_50k.csv')
# Out:
# <ipython-input-12-3c16f56a4b81>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/airline_dec_2008_50k.csv')

# %%
dfduplicate = df.append(df)
# Out:
# <ipython-input-13-02f9cce6ea2b>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfduplicate = df.append(df)

# %%
dfduplicate = dfduplicate.sample(frac=1)

# %%
dfclean = dfduplicate.drop_duplicates()

# %%
len(dfclean) == len(df)
# Out:
# True

# %%
len(dfclean)
# Out:
# 50000

# %%
dfclean.drop_duplicates(subset='DayofMonth')
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 38176       38177  2008     12           8          1    917.0         920
# 39676       39677  2008     12           9          2    707.0         700
# 2872         2873  2008     12          11          4      NaN        1435
# 4422         4423  2008     12          15          1      NaN         804
# 3473         3474  2008     12          12          5      NaN        1910
# 32459       32460  2008     12           6          6    600.0         608
# 34715       34716  2008     12           7          7    639.0         645
# 23307       23308  2008     12           2          2    657.0         707
# 14986       14987  2008     12          26          5      NaN         740
# 30798       30799  2008     12           5          5    647.0         655
# 2362         2363  2008     12          10          3      NaN        1706
# 21529       21530  2008     12           1          1    834.0         825
# 29114       29115  2008     12           4          4    745.0         745
# 16999       17000  2008     12          31          3      NaN         909
# 6290         6291  2008     12          18          4      NaN        1011
# 642           643  2008     12           3          3      NaN        1400
# 15715       15716  2008     12          27          6      NaN         735
# 48495       48496  2008     12          13          6    551.0         600
# 19166       19167  2008     12          28          7     45.0          55
# 21943       21944  2008     12          22          1   1846.0        1834
# 11084       11085  2008     12          21          7      NaN        1915
# 9214         9215  2008     12          19          5      NaN         935
# 12977       12978  2008     12          23          2      NaN        1652
# 16348       16349  2008     12          30          2      NaN        1847
# 17829       17830  2008     12          17          3   1355.0        1330
# 4711         4712  2008     12          16          2      NaN        1500
# 17265       17266  2008     12          25          4    812.0         659
# 9625         9626  2008     12          20          6      NaN        1845
# 16172       16173  2008     12          29          1      NaN        1900
# 3795         3796  2008     12          14          7      NaN        1529
# 13500       13501  2008     12          24          3      NaN        1550
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 38176    951.0         950            WN  ...     7.0    19.0          0
# 39676    928.0         924            CO  ...     4.0    11.0          0
# 2872       NaN        1604            OH  ...     NaN     NaN          1
# 4422       NaN        1010            UA  ...     NaN     NaN          1
# 3473       NaN        1958            OO  ...     NaN     NaN          1
# 32459    708.0         735            OO  ...     4.0    11.0          0
# 34715    951.0         957            XE  ...     6.0    24.0          0
# 23307    905.0         910            YV  ...    17.0    16.0          0
# 14986      NaN        1030            WN  ...     NaN     NaN          1
# 30798    931.0         950            AS  ...     5.0    13.0          0
# 2362       NaN        1808            DL  ...     NaN     NaN          1
# 21529    954.0         958            UA  ...     5.0    14.0          0
# 29114    901.0         905            WN  ...     4.0     6.0          0
# 16999      NaN        1004            YV  ...     NaN     NaN          1
# 6290       NaN        1230            FL  ...     NaN     NaN          1
# 642        NaN        1650            AS  ...     NaN     NaN          1
# 15715      NaN         826            OO  ...     NaN     NaN          1
# 48495    824.0         850            AA  ...     3.0    11.0          0
# 19166    615.0         625            B6  ...     9.0    16.0          0
# 21943      3.0          12            CO  ...     7.0     8.0          0
# 11084      NaN        2035            XE  ...     NaN     NaN          1
# 9214       NaN        1335            AA  ...     NaN     NaN          1
# 12977      NaN        1805            UA  ...     NaN     NaN          1
# 16348      NaN        1919            YV  ...     NaN     NaN          1
# 17829      NaN        1600            WN  ...     NaN    10.0          0
# 4711       NaN        1708            DL  ...     NaN     NaN          1
# 17265      NaN        1005            OO  ...     NaN    12.0          0
# 9625       NaN        2207            B6  ...     NaN     NaN          1
# 16172      NaN        2000            WN  ...     NaN     NaN          1
# 3795       NaN        1606            OO  ...     NaN     NaN          1
# 13500      NaN        1716            FL  ...     NaN     NaN          1
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 38176               NaN         0           NaN           NaN      NaN
# 39676               NaN         0           NaN           NaN      NaN
# 2872                  B         0           NaN           NaN      NaN
# 4422                  B         0           NaN           NaN      NaN
# 3473                  B         0           NaN           NaN      NaN
# 32459               NaN         0           NaN           NaN      NaN
# 34715               NaN         0           NaN           NaN      NaN
# 23307               NaN         0           NaN           NaN      NaN
# 14986                 B         0           NaN           NaN      NaN
# 30798               NaN         0           NaN           NaN      NaN
# 2362                  C         0           NaN           NaN      NaN
# 21529               NaN         0           NaN           NaN      NaN
# 29114               NaN         0           NaN           NaN      NaN
# 16999                 A         0           NaN           NaN      NaN
# 6290                  A         0           NaN           NaN      NaN
# 642                   A         0           NaN           NaN      NaN
# 15715                 B         0           NaN           NaN      NaN
# 48495               NaN         0           NaN           NaN      NaN
# 19166               NaN         0           NaN           NaN      NaN
# 21943               NaN         0           NaN           NaN      NaN
# 11084                 B         0           NaN           NaN      NaN
# 9214                  B         0           NaN           NaN      NaN
# 12977                 C         0           NaN           NaN      NaN
# 16348                 A         0           NaN           NaN      NaN
# 17829               NaN         1           NaN           NaN      NaN
# 4711                  B         0           NaN           NaN      NaN
# 17265               NaN         1           NaN           NaN      NaN
# 9625                  B         0           NaN           NaN      NaN
# 16172                 A         0           NaN           NaN      NaN
# 3795                  C         0           NaN           NaN      NaN
# 13500                 A         0           NaN           NaN      NaN
#
#       SecurityDelay  LateAircraftDelay
# 38176           NaN                NaN
# 39676           NaN                NaN
# 2872            NaN                NaN
# 4422            NaN                NaN
# 3473            NaN                NaN
# 32459           NaN                NaN
# 34715           NaN                NaN
# 23307           NaN                NaN
# 14986           NaN                NaN
# 30798           NaN                NaN
# 2362            NaN                NaN
# 21529           NaN                NaN
# 29114           NaN                NaN
# 16999           NaN                NaN
# 6290            NaN                NaN
# 642             NaN                NaN
# 15715           NaN                NaN
# 48495           NaN                NaN
# 19166           NaN                NaN
# 21943           NaN                NaN
# 11084           NaN                NaN
# 9214            NaN                NaN
# 12977           NaN                NaN
# 16348           NaN                NaN
# 17829           NaN                NaN
# 4711            NaN                NaN
# 17265           NaN                NaN
# 9625            NaN                NaN
# 16172           NaN                NaN
# 3795            NaN                NaN
# 13500           NaN                NaN
#
# [31 rows x 30 columns]

# %%
df.dropna() #datos faltantes
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 30 columns]

# %%
df.dropna(thresh=25)
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 17622       17623  2008     12           1          1      7.0          10
# 18122       18123  2008     12          20          6      3.0        2310
# 18600       18601  2008     12           8          1      3.0        2325
# 18605       18606  2008     12           1          1     15.0        2115
# 18606       18607  2008     12           1          1     16.0          20
# ...           ...   ...    ...         ...        ...      ...         ...
# 49948       49949  2008     12          13          6    759.0         738
# 49956       49957  2008     12          13          6    800.0         746
# 49966       49967  2008     12          13          6    801.0         740
# 49967       49968  2008     12          13          6    801.0         740
# 49991       49992  2008     12          13          6    804.0         805
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 17622    659.0         629            DL  ...    28.0    15.0          0
# 18122     58.0           5            AA  ...     5.0    15.0          0
# 18600     51.0          20            AA  ...     6.0     9.0          0
# 18605    329.0           5            MQ  ...     3.0    46.0          0
# 18606    616.0         553            NW  ...    13.0    14.0          0
# ...        ...         ...           ...  ...     ...     ...        ...
# 49948    910.0         847            AS  ...     4.0     5.0          0
# 49956    903.0         846            OO  ...     4.0    18.0          0
# 49966    926.0         900            AA  ...    20.0    11.0          0
# 49967    943.0         900            MQ  ...    11.0    37.0          0
# 49991    943.0         910            WN  ...    10.0    16.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 17622               NaN         0           0.0           0.0     30.0
# 18122               NaN         0           8.0           0.0      0.0
# 18600               NaN         0          31.0           0.0      0.0
# 18605               NaN         0          38.0           0.0     24.0
# 18606               NaN         0           0.0           0.0     23.0
# ...                 ...       ...           ...           ...      ...
# 49948               NaN         0           0.0           0.0      2.0
# 49956               NaN         0           9.0           0.0      3.0
# 49966               NaN         0          11.0           0.0      5.0
# 49967               NaN         0          21.0           0.0     22.0
# 49991               NaN         0           0.0           0.0     33.0
#
#       SecurityDelay  LateAircraftDelay
# 17622           0.0                0.0
# 18122           0.0               45.0
# 18600           0.0                0.0
# 18605           0.0              142.0
# 18606           0.0                0.0
# ...             ...                ...
# 49948           0.0               21.0
# 49956           0.0                5.0
# 49966           0.0               10.0
# 49967           0.0                0.0
# 49991           0.0                0.0
#
# [4157 rows x 30 columns]

# %%
df.dropna(thresh=len(df.columns)-2)
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 17622       17623  2008     12           1          1      7.0          10
# 18122       18123  2008     12          20          6      3.0        2310
# 18600       18601  2008     12           8          1      3.0        2325
# 18605       18606  2008     12           1          1     15.0        2115
# 18606       18607  2008     12           1          1     16.0          20
# ...           ...   ...    ...         ...        ...      ...         ...
# 49948       49949  2008     12          13          6    759.0         738
# 49956       49957  2008     12          13          6    800.0         746
# 49966       49967  2008     12          13          6    801.0         740
# 49967       49968  2008     12          13          6    801.0         740
# 49991       49992  2008     12          13          6    804.0         805
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 17622    659.0         629            DL  ...    28.0    15.0          0
# 18122     58.0           5            AA  ...     5.0    15.0          0
# 18600     51.0          20            AA  ...     6.0     9.0          0
# 18605    329.0           5            MQ  ...     3.0    46.0          0
# 18606    616.0         553            NW  ...    13.0    14.0          0
# ...        ...         ...           ...  ...     ...     ...        ...
# 49948    910.0         847            AS  ...     4.0     5.0          0
# 49956    903.0         846            OO  ...     4.0    18.0          0
# 49966    926.0         900            AA  ...    20.0    11.0          0
# 49967    943.0         900            MQ  ...    11.0    37.0          0
# 49991    943.0         910            WN  ...    10.0    16.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 17622               NaN         0           0.0           0.0     30.0
# 18122               NaN         0           8.0           0.0      0.0
# 18600               NaN         0          31.0           0.0      0.0
# 18605               NaN         0          38.0           0.0     24.0
# 18606               NaN         0           0.0           0.0     23.0
# ...                 ...       ...           ...           ...      ...
# 49948               NaN         0           0.0           0.0      2.0
# 49956               NaN         0           9.0           0.0      3.0
# 49966               NaN         0          11.0           0.0      5.0
# 49967               NaN         0          21.0           0.0     22.0
# 49991               NaN         0           0.0           0.0     33.0
#
#       SecurityDelay  LateAircraftDelay
# 17622           0.0                0.0
# 18122           0.0               45.0
# 18600           0.0                0.0
# 18605           0.0              142.0
# 18606           0.0                0.0
# ...             ...                ...
# 49948           0.0               21.0
# 49956           0.0                5.0
# 49966           0.0               10.0
# 49967           0.0                0.0
# 49991           0.0                0.0
#
# [4157 rows x 30 columns]

# %%
df.dropna(subset= ['CancellationCode'])
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0               1  2008     12           1          1      NaN        1000
# 1               2  2008     12           1          1      NaN        1000
# 2               3  2008     12           1          1      NaN        1000
# 3               4  2008     12           1          1      NaN        1000
# 4               5  2008     12           1          1      NaN        1000
# ...           ...   ...    ...         ...        ...      ...         ...
# 18575       18576  2008     12          31          3   1552.0        1425
# 18578       18579  2008     12          31          3   1650.0        1656
# 18580       18581  2008     12          31          3   1749.0        1755
# 18581       18582  2008     12          31          3   1800.0        1800
# 18590       18591  2008     12          31          3   2015.0        1947
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0          NaN        1100            WN  ...     NaN     NaN          1
# 1          NaN        1110            US  ...     NaN     NaN          1
# 2          NaN        1125            MQ  ...     NaN     NaN          1
# 3          NaN        1227            EV  ...     NaN     NaN          1
# 4          NaN        1227            NW  ...     NaN     NaN          1
# ...        ...         ...           ...  ...     ...     ...        ...
# 18575      NaN        1505            MQ  ...     NaN    17.0          1
# 18578      NaN        1810            OH  ...     NaN     NaN          1
# 18580      NaN        1920            F9  ...     NaN     NaN          1
# 18581      NaN        1834            YV  ...     NaN    20.0          1
# 18590      NaN        2258            UA  ...     NaN     NaN          1
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                     A         0           NaN           NaN      NaN
# 1                     A         0           NaN           NaN      NaN
# 2                     B         0           NaN           NaN      NaN
# 3                     C         0           NaN           NaN      NaN
# 4                     B         0           NaN           NaN      NaN
# ...                 ...       ...           ...           ...      ...
# 18575                 B         0           NaN           NaN      NaN
# 18578                 B         0           NaN           NaN      NaN
# 18580                 B         0           NaN           NaN      NaN
# 18581                 B         0           NaN           NaN      NaN
# 18590                 A         0           NaN           NaN      NaN
#
#       SecurityDelay  LateAircraftDelay
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# ...             ...                ...
# 18575           NaN                NaN
# 18578           NaN                NaN
# 18580           NaN                NaN
# 18581           NaN                NaN
# 18590           NaN                NaN
#
# [17779 rows x 30 columns]
